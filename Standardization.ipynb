# %% [markdown]
# #**STANDARDIZATION**

# %% [markdown]
# Standardisation with helps you to scale down your feature based on standard
#
# normal distribution
#
# Here standard deviation is 1 and mean is usually 0
#
# class used for standarisation is called StandardScalar
#
# z=(x-u)/s
#
# where u is the mean of the training samples and s is the standard deviation
#
# of the training samples

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/datascience/Machine Learning/Machine Learning Algorithms/KNN/Standardization And Normalization/salary_data (2) (1).csv')

# %%
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
print(dataset.head())
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
print(dataset.shape)
# Out:
# (30, 2)

# %%
x = dataset.iloc[:,:-1].values   #get a copy of dataset excluding last column

# %%
y = dataset.iloc[:,1].values  #get array of dataset in columnlist

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
# Split the dataset into the training set and testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 1/3,random_state = 0)

# %%
plt.plot(x_train)

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

# %%
x_train = std.fit_transform(x_train)

#std.fit(X_test)
x_test = std.transform(x_test)

# %%
plt.plot(x_train)

# %% [markdown]
# # **NORMALIZATION**

# %% [markdown]
# Normalisation helps you to scale down your feature between e and 1
#
# Normalisation is also called MinMaxscalar
#
# class used for Normalisation is called MinMaxscalar

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dataset1 = pd.read_csv('/content/drive/MyDrive/datascience/Machine Learning/Machine Learning Algorithms/KNN/Standardization And Normalization/salary_data (2) (1).csv')

# %%
dataset1.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
print(dataset1.shape)
# Out:
# (30, 2)

# %%
x = dataset1.iloc[:,:-1].values   #get a copy of dataset excluding last column

# %%
y = dataset1.iloc[:,1].values  #get array of dataset in columnlist

# %%
print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
print(y)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
# Split the dataset into the training set and testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 1/3,random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(x_train)

scaler.transform(x_train)
# Out:
# array([[0.19148936],
#        [0.42553191],
#        [0.22340426],
#        [0.36170213],
#        [0.75531915],
#        [0.60638298],
#        [0.0212766 ],
#        [1.        ],
#        [0.20212766],
#        [0.11702128],
#        [0.5106383 ],
#        [0.5212766 ],
#        [0.27659574],
#        [0.22340426],
#        [0.84042553],
#        [0.09574468],
#        [0.        ],
#        [0.63829787],
#        [0.40425532],
#        [0.30851064]])
